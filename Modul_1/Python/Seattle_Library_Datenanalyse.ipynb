# %% [markdown]
# # Seattle Library - Datenanalyse
#
# Datasets:
# - [Checkouts by Title](https://dev.socrata.com/foundry/data.seattle.gov/tmmm-ytt6)
# - [Library Collection Inventory](https://data.seattle.gov/Community/Library-Collection-Inventory/6vkj-f5xf)
#
# API-documentation:
#
# - Paging trough Data [https://dev.socrata.com/docs/paging.html](https://dev.socrata.com/docs/paging.html)
# - Queries using Soda [https://dev.socrata.com/docs/queries/](https://dev.socrata.com/docs/queries/)

# %%
import urllib.request
import pandas as pd

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2021&$limit=50000"
checkout_file = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7f284915d4f0>)

# %%
checkouts_df = pd.read_csv(checkout_file)

# %%
checkouts_df
# Out:
#       usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0        Digital    OverDrive        EBOOK          2021              1
# 1        Digital    OverDrive        EBOOK          2021              1
# 2        Digital    OverDrive        EBOOK          2021              1
# 3        Digital    OverDrive        EBOOK          2021              1
# 4        Digital    OverDrive    AUDIOBOOK          2021              1
# ...          ...          ...          ...           ...            ...
# 49995   Physical      Horizon         BOOK          2021              1
# 49996    Digital    OverDrive    AUDIOBOOK          2021              1
# 49997    Digital    OverDrive    AUDIOBOOK          2021              1
# 49998    Digital    OverDrive        EBOOK          2021              1
# 49999    Digital    OverDrive        EBOOK          2021              1
#
#        checkouts                                              title  \
# 0              4                                          Plainsong
# 1              1                               Second Life: A Novel
# 2              1             Ethan in Gold: Johnnies Series, Book 3
# 3              2                            Beauchamp Hall: A Novel
# 4              2                               Shardik (Unabridged)
# ...          ...                                                ...
# 49995          1  The faceless old woman who secretly lives in y...
# 49996          1  Not Fade Away: A Memoir of Senses Lost and Fou...
# 49997          2                        Kill the Queen (Unabridged)
# 49998          2  The Democracy Project: A History, a Crisis, a ...
# 49999          1                                The Cinnamon Peeler
#
#                              creator  \
# 0                         Kent Haruf
# 1                       S. J. Watson
# 2                           Amy Lane
# 3                     Danielle Steel
# 4                      Richard Adams
# ...                              ...
# 49995  Fink, Joseph (Fiction writer)
# 49996              Rebecca Alexander
# 49997                 Jennifer Estep
# 49998                  David Graeber
# 49999               Michael Ondaatje
#
#                                                 subjects  \
# 0                                    Fiction, Literature
# 1                            Fiction, Suspense, Thriller
# 2                                       Fiction, Romance
# 3                                       Fiction, Romance
# 4                                    Fiction, Literature
# ...                                                  ...
# 49995  Southwestern States Fiction, Ghost stories, Sc...
# 49996  Biography & Autobiography, Nonfiction, Self-Im...
# 49997                          Fantasy, Fiction, Romance
# 49998           History, Nonfiction, Politics, Sociology
# 49999                           Fiction, Poetry, Romance
#
#                            publisher publicationyear
# 0                 Random House, Inc.            2012
# 1      HarperCollins Publishers Inc.            2015
# 2                 Dreamspinner Press            2014
# 3                 Random House, Inc.            2018
# 4             Blackstone Audio, Inc.            2017
# ...                              ...             ...
# 49995              Harper Perennial,          [2020]
# 49996              Tantor Media, Inc            2014
# 49997  HarperCollins Publishers Inc.            2018
# 49998             Random House, Inc.            2013
# 49999             Random House, Inc.            2011
#
# [50000 rows x 11 columns]

# %%
checkouts_df.columns
# Out:
# Index(['usageclass', 'checkouttype', 'materialtype', 'checkoutyear',
#        'checkoutmonth', 'checkouts', 'title', 'creator', 'subjects',
#        'publisher', 'publicationyear'],
#       dtype='object')

# %%
checkouts_df.shape
# Out:
# (50000, 11)

# %%
checkouts_df["checkouts"].max()
# Out:
# 820

# %%
checkouts_df["checkouts"].min()
# Out:
# 1

# %%
checkouts_df["checkouts"].median()
# Out:
# 2.0

# %%
checkouts_df["checkouts"].mean()
# Out:
# 3.32402

# %%
checkouts_df["materialtype"].unique()
# Out:
# array(['EBOOK', 'AUDIOBOOK', 'BOOK', 'SOUNDDISC', 'VIDEODISC',
#        'SOUNDDISC, VIDEODISC', 'REGPRINT', 'ATLAS', 'VIDEO', 'MUSIC',
#        'MICROFORM', 'MAP', 'ER', 'CR', 'LARGEPRINT', 'SOUNDREC',
#        'ER, SOUNDDISC', 'SOUNDDISC, SOUNDREC', 'REGPRINT, SOUNDDISC',
#        'ER, VIDEODISC', 'MUSICSNDREC', 'VISUAL'], dtype=object)

# %%
checkouts_df[checkouts_df["materialtype"] == "EBOOK"]
# Out:
#       usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0        Digital    OverDrive        EBOOK          2021              1
# 1        Digital    OverDrive        EBOOK          2021              1
# 2        Digital    OverDrive        EBOOK          2021              1
# 3        Digital    OverDrive        EBOOK          2021              1
# 5        Digital    OverDrive        EBOOK          2021              1
# ...          ...          ...          ...           ...            ...
# 49984    Digital    OverDrive        EBOOK          2021              1
# 49985    Digital    OverDrive        EBOOK          2021              1
# 49990    Digital    OverDrive        EBOOK          2021              1
# 49998    Digital    OverDrive        EBOOK          2021              1
# 49999    Digital    OverDrive        EBOOK          2021              1
#
#        checkouts                                              title  \
# 0              4                                          Plainsong
# 1              1                               Second Life: A Novel
# 2              1             Ethan in Gold: Johnnies Series, Book 3
# 3              2                            Beauchamp Hall: A Novel
# 5              4                                Earthly Possessions
# ...          ...                                                ...
# 49984          1                                          The Exile
# 49985          1                                         Blackmoore
# 49990          1                                       Intervention
# 49998          2  The Democracy Project: A History, a Crisis, a ...
# 49999          1                                The Cinnamon Peeler
#
#                   creator                                  subjects  \
# 0              Kent Haruf                       Fiction, Literature
# 1            S. J. Watson               Fiction, Suspense, Thriller
# 2                Amy Lane                          Fiction, Romance
# 3          Danielle Steel                          Fiction, Romance
# 5              Anne Tyler                       Fiction, Literature
# ...                   ...                                       ...
# 49984      Andrew Britton                         Fiction, Thriller
# 49985  Julianne Donaldson      Fiction, Historical Fiction, Romance
# 49990    Terri Blackstock       Fiction, Mystery, Romance, Suspense
# 49998       David Graeber  History, Nonfiction, Politics, Sociology
# 49999    Michael Ondaatje                  Fiction, Poetry, Romance
#
#                                 publisher publicationyear
# 0                      Random House, Inc.            2012
# 1           HarperCollins Publishers Inc.            2015
# 2                      Dreamspinner Press            2014
# 3                      Random House, Inc.            2018
# 5                      Random House, Inc.            2011
# ...                                   ...             ...
# 49984                Lightning Source Inc            2011
# 49985                      Libros de Seda            2018
# 49990  HarperCollins Christian Publishing            2013
# 49998                  Random House, Inc.            2013
# 49999                  Random House, Inc.            2011
#
# [19398 rows x 11 columns]

# %%
checkouts_ebooks_df = checkouts_df[checkouts_df["materialtype"] == "EBOOK"]

# %%
checkouts_ebooks_Random_df = checkouts_ebooks_df[checkouts_ebooks_df["publisher"] == "Random House, Inc."]

# %%
checkouts_ebooks_Random_df[checkouts_ebooks_Random_df["publisher"] == "Random House, Inc."]
# Out:
#       usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0        Digital    OverDrive        EBOOK          2021              1
# 3        Digital    OverDrive        EBOOK          2021              1
# 5        Digital    OverDrive        EBOOK          2021              1
# 10       Digital    OverDrive        EBOOK          2021              1
# 12       Digital    OverDrive        EBOOK          2021              1
# ...          ...          ...          ...           ...            ...
# 49930    Digital    OverDrive        EBOOK          2021              1
# 49956    Digital    OverDrive        EBOOK          2021              1
# 49975    Digital    OverDrive        EBOOK          2021              1
# 49998    Digital    OverDrive        EBOOK          2021              1
# 49999    Digital    OverDrive        EBOOK          2021              1
#
#        checkouts                                              title  \
# 0              4                                          Plainsong
# 3              2                            Beauchamp Hall: A Novel
# 5              4                                Earthly Possessions
# 10             2                           Fall from Grace: A Novel
# 12             1                          The Peach Keeper: A Novel
# ...          ...                                                ...
# 49930          1                          Midnight Warrior: A Novel
# 49956          1                    Around the World in Eighty Days
# 49975          1                                  DEV1AT3 (Deviate)
# 49998          2  The Democracy Project: A History, a Crisis, a ...
# 49999          1                                The Cinnamon Peeler
#
#                    creator                                           subjects  \
# 0               Kent Haruf                                Fiction, Literature
# 3           Danielle Steel                                   Fiction, Romance
# 5               Anne Tyler                                Fiction, Literature
# 10          Danielle Steel                       Fiction, Literature, Romance
# 12     Sarah Addison Allen                                Fiction, Literature
# ...                    ...                                                ...
# 49930        Iris Johansen               Fiction, Historical Fiction, Romance
# 49956          Jules Verne  Classic Literature, Fiction, Literature, Thriller
# 49975         Jay Kristoff  Romance, Science Fiction, Young Adult Fiction,...
# 49998        David Graeber           History, Nonfiction, Politics, Sociology
# 49999     Michael Ondaatje                           Fiction, Poetry, Romance
#
#                 publisher publicationyear
# 0      Random House, Inc.            2012
# 3      Random House, Inc.            2018
# 5      Random House, Inc.            2011
# 10     Random House, Inc.            2018
# 12     Random House, Inc.            2011
# ...                   ...             ...
# 49930  Random House, Inc.            2012
# 49956  Random House, Inc.            2010
# 49975  Random House, Inc.            2019
# 49998  Random House, Inc.            2013
# 49999  Random House, Inc.            2011
#
# [3899 rows x 11 columns]

# %%
checkouts_ebooks_Random_df.sort_values(by=["checkouts"], ascending=False)[["publisher", "title", "creator", "checkouts"]]
# Out:
#                 publisher                                              title  \
# 24251  Random House, Inc.                                            Untamed
# 10791  Random House, Inc.  Caste (Oprah's Book Club): The Origins of Our ...
# 25848  Random House, Inc.                            Sex and Vanity: A Novel
# 23146  Random House, Inc.  White Fragility: Why It's So Hard for White Pe...
# 16111  Random House, Inc.                      Before We Were Yours: A Novel
# ...                   ...                                                ...
# 23632  Random House, Inc.      Complete Stories and Poems of Edgar Allan Poe
# 23517  Random House, Inc.                                      Aria: A Novel
# 23476  Random House, Inc.                     The Best Buddhist Writing 2013
# 23413  Random House, Inc.  Seattle Justice: The Rise and Fall of the Poli...
# 49999  Random House, Inc.                                The Cinnamon Peeler
#
#                      creator  checkouts
# 24251          Glennon Doyle        314
# 10791       Isabel Wilkerson        307
# 25848             Kevin Kwan        222
# 23146         Robin DiAngelo        174
# 16111           Lisa Wingate        125
# ...                      ...        ...
# 23632        Edgar Allan Poe          1
# 23517         Nazanine Hozar          1
# 23476          Melvin McLeod          1
# 23413  Christopher T. Bayley          1
# 49999       Michael Ondaatje          1
#
# [3899 rows x 4 columns]

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# TOP 10 Random-Titel
checkouts_ebooks_Random_df.hist("checkouts", bins=10, color="blue")
# Out:
# array([[<AxesSubplot:title={'center':'checkouts'}>]], dtype=object)
