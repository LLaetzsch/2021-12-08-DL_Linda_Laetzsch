# %% [markdown]
# # Jupyter Notebook Beispiel
#
# - Das hier ist eine Text-Zelle geschrieben in [Markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet).
# - Mit einem Doppelklick in die Zelle, können Sie den Text bearbeiten.
# - Mit einem Klick auf den `Run` Button oder mit der Tastenkombinaion `Strg`+`Enter` können Sie Code in Zellen ausführen oder Markdown Text rendern.
# - 2022-03-07 Linda Lätzsch

# %%
# das hier ist eine Zelle mit Programmcode!

# zuerst werden die benötgten libraries importiert
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# sns.set() verschönert das Aussehen der plots
sns.set()

# 100 normalverteilte Zahlen werden generiert
random_numbers = np.random.normal(size = 100)

# der plot wird erstellt
plot = sns.distplot(random_numbers, color="red")
plot = plot.set_title('normal distributed random numbers')
plot
# Out:
# /home/linda/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'normal distributed random numbers')

# %%
# Warum kommt jedes Mal ein anderer Graph raus, wenn man den "Run" Button klickt oder "Strg+Enter" ausführt?
# Wie können beim zweiten und dritten Versuch die Balken voneinander getrennt werden?

# %%
# Zweiter Versuch mit histplot

# zuerst werden die benötgten libraries importiert
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# sns.set() verschönert das Aussehen der plots
sns.set()

# 100 normalverteilte Zahlen werden generiert
random_numbers = np.random.normal(size = 100)

# der plot wird erstellt
plot = sns.histplot(random_numbers, color="red", kde=True, stat="density", linewidth=0)
plot = plot.set_title('normal distributed random numbers')
plot
# Out:
# Text(0.5, 1.0, 'normal distributed random numbers')

# %%
# Dritter Versuch mit displot

# zuerst werden die benötgten libraries importiert
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# sns.set() verschönert das Aussehen der plots
sns.set()

# 100 normalverteilte Zahlen werden generiert
random_numbers = np.random.normal(size = 80)

# der plot wird erstellt
plot = sns.displot(random_numbers, color="red", kde=True, stat="density", linewidth=0)
plot.fig.suptitle("normal distributed random numbers", fontsize=12, fontdict={"weight": "bold"})
plot
